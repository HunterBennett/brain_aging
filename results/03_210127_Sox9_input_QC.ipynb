# %%
### header ###
__author__ = "Hunter Bennett"
__license__ = "BSD"
__email__ = "hunter.r.bennett@gmail.com"
# %load_ext autoreload
# %autoreload 2
### imports ###
import sys
# %matplotlib inline
import os
import re
import glob
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 200
sns.set(font_scale=1)
sns.set_context('talk')
sns.set_style('white')

# import custom functions
import sys
sys.path.insert(0, '/home/h1bennet/code/')
from hbUtils import ngs_qc, quantile_normalize_df

# %% [markdown]
# Set working directory

# %%
dataDirectory = '/data/mm10/Brain_MPSIIIA/ChIP/input/SOX9/'
workingDirectory = '/home/h1bennet/mpsiiia/results/03_Sox9_H3K27Ac_QC/'
if not os.path.isdir(workingDirectory):
    os.mkdir(workingDirectory)
os.chdir(workingDirectory)

# %% [markdown]
# # Quality control

# %%
qc = ngs_qc(dataDirectory, 'atac')
# Out:
# /data/mm10/Brain_MPSIIIA/ChIP/input/SOX9//
# ./SOX9_qc/

# %%
qc
# Out:
#                                                     uniquePositions  \
# 00_mouse_BL6_M_3week_SOX9_input_AL_l20200911_TC...        6635184.0
# 01_mouse_BL6_M_3month_SOX9_input_13_JOS_l202002...       12299688.0
# 01_mouse_BL6_M_3month_SOX9_input_14_JOS_l202002...       26467674.0
# 01_mouse_BL6_M_3month_SOX9_input_1_AL_20200205_...       23539893.0
# 01_mouse_BL6_M_3month_SOX9_input_2012_JOS_l2020...       13232825.0
# 01_mouse_BL6_M_3month_SOX9_input_2_AL_20200205_...       12299688.0
# 01_mouse_BL6_M_3month_SOX9_input_BL6_1_input_AL...       11205285.0
# 02_mouse_MPSIIIAhet_M_4month_SOX9_input_4_AL_l2...       12985619.0
# 03_mouse_BL6_M_26month_SOX9_input_AL_l20200911_...        3708136.0
#
#                                                     fragmentLengthEstimate  \
# 00_mouse_BL6_M_3week_SOX9_input_AL_l20200911_TC...                   225.0
# 01_mouse_BL6_M_3month_SOX9_input_13_JOS_l202002...                    80.0
# 01_mouse_BL6_M_3month_SOX9_input_14_JOS_l202002...                    80.0
# 01_mouse_BL6_M_3month_SOX9_input_1_AL_20200205_...                    82.0
# 01_mouse_BL6_M_3month_SOX9_input_2012_JOS_l2020...                    81.0
# 01_mouse_BL6_M_3month_SOX9_input_2_AL_20200205_...                    80.0
# 01_mouse_BL6_M_3month_SOX9_input_BL6_1_input_AL...                    80.0
# 02_mouse_MPSIIIAhet_M_4month_SOX9_input_4_AL_l2...                   188.0
# 03_mouse_BL6_M_26month_SOX9_input_AL_l20200911_...                    80.0
#
#                                                     tagsPerBP  clonality  \
# 00_mouse_BL6_M_3week_SOX9_input_AL_l20200911_TC...   0.003255      1.337
# 01_mouse_BL6_M_3month_SOX9_input_13_JOS_l202002...   0.004789      1.061
# 01_mouse_BL6_M_3month_SOX9_input_14_JOS_l202002...   0.010484      1.080
# 01_mouse_BL6_M_3month_SOX9_input_1_AL_20200205_...   0.009597      1.111
# 01_mouse_BL6_M_3month_SOX9_input_2012_JOS_l2020...   0.005220      1.075
# 01_mouse_BL6_M_3month_SOX9_input_2_AL_20200205_...   0.004789      1.061
# 01_mouse_BL6_M_3month_SOX9_input_BL6_1_input_AL...   0.004377      1.065
# 02_mouse_MPSIIIAhet_M_4month_SOX9_input_4_AL_l2...   0.005043      1.059
# 03_mouse_BL6_M_26month_SOX9_input_AL_l20200911_...   0.003359      2.469
#
#                                                       GC_Content  totalReads  \
# 00_mouse_BL6_M_3week_SOX9_input_AL_l20200911_TC...  3.970000e-01  10687767.0
# 01_mouse_BL6_M_3month_SOX9_input_13_JOS_l202002...  3.990000e-01  16768327.0
# 01_mouse_BL6_M_3month_SOX9_input_14_JOS_l202002...  4.050000e-01  37127723.0
# 01_mouse_BL6_M_3month_SOX9_input_1_AL_20200205_...  2.726366e+09         0.0
# 01_mouse_BL6_M_3month_SOX9_input_2012_JOS_l2020...  3.930000e-01  18352055.0
# 01_mouse_BL6_M_3month_SOX9_input_2_AL_20200205_...  3.990000e-01  16768327.0
# 01_mouse_BL6_M_3month_SOX9_input_BL6_1_input_AL...  3.940000e-01  15415540.0
# 02_mouse_MPSIIIAhet_M_4month_SOX9_input_4_AL_l2...  4.190000e-01  18022575.0
# 03_mouse_BL6_M_26month_SOX9_input_AL_l20200911_...  3.910000e-01  11912955.0
#
#                                                     uniquelyMappedReads  \
# 00_mouse_BL6_M_3week_SOX9_input_AL_l20200911_TC...            7862767.0
# 01_mouse_BL6_M_3month_SOX9_input_13_JOS_l202002...           11899363.0
# 01_mouse_BL6_M_3month_SOX9_input_14_JOS_l202002...           25885671.0
# 01_mouse_BL6_M_3month_SOX9_input_1_AL_20200205_...                  0.0
# 01_mouse_BL6_M_3month_SOX9_input_2012_JOS_l2020...           13001617.0
# 01_mouse_BL6_M_3month_SOX9_input_2_AL_20200205_...           11899363.0
# 01_mouse_BL6_M_3month_SOX9_input_BL6_1_input_AL...           10862729.0
# 02_mouse_MPSIIIAhet_M_4month_SOX9_input_4_AL_l2...           12533806.0
# 03_mouse_BL6_M_26month_SOX9_input_AL_l20200911_...            8185244.0
#
#                                                     multiMappedReads  \
# 00_mouse_BL6_M_3week_SOX9_input_AL_l20200911_TC...         2593163.0
# 01_mouse_BL6_M_3month_SOX9_input_13_JOS_l202002...         4218241.0
# 01_mouse_BL6_M_3month_SOX9_input_14_JOS_l202002...         9619284.0
# 01_mouse_BL6_M_3month_SOX9_input_1_AL_20200205_...               0.0
# 01_mouse_BL6_M_3month_SOX9_input_2012_JOS_l2020...         4504145.0
# 01_mouse_BL6_M_3month_SOX9_input_2_AL_20200205_...         4218241.0
# 01_mouse_BL6_M_3month_SOX9_input_BL6_1_input_AL...         3789362.0
# 02_mouse_MPSIIIAhet_M_4month_SOX9_input_4_AL_l2...         4601966.0
# 03_mouse_BL6_M_26month_SOX9_input_AL_l20200911_...         3093263.0
#
#                                                     unmappedReads  \
# 00_mouse_BL6_M_3week_SOX9_input_AL_l20200911_TC...       231837.0
# 01_mouse_BL6_M_3month_SOX9_input_13_JOS_l202002...       650723.0
# 01_mouse_BL6_M_3month_SOX9_input_14_JOS_l202002...      1622768.0
# 01_mouse_BL6_M_3month_SOX9_input_1_AL_20200205_...            NaN
# 01_mouse_BL6_M_3month_SOX9_input_2012_JOS_l2020...       846293.0
# 01_mouse_BL6_M_3month_SOX9_input_2_AL_20200205_...       650723.0
# 01_mouse_BL6_M_3month_SOX9_input_BL6_1_input_AL...       763449.0
# 02_mouse_MPSIIIAhet_M_4month_SOX9_input_4_AL_l2...       886803.0
# 03_mouse_BL6_M_26month_SOX9_input_AL_l20200911_...       634448.0
#
#                                                     uniquelyMappedFraction  \
# 00_mouse_BL6_M_3week_SOX9_input_AL_l20200911_TC...                0.735679
# 01_mouse_BL6_M_3month_SOX9_input_13_JOS_l202002...                0.709633
# 01_mouse_BL6_M_3month_SOX9_input_14_JOS_l202002...                0.697206
# 01_mouse_BL6_M_3month_SOX9_input_1_AL_20200205_...                0.000000
# 01_mouse_BL6_M_3month_SOX9_input_2012_JOS_l2020...                0.708456
# 01_mouse_BL6_M_3month_SOX9_input_2_AL_20200205_...                0.709633
# 01_mouse_BL6_M_3month_SOX9_input_BL6_1_input_AL...                0.704661
# 02_mouse_MPSIIIAhet_M_4month_SOX9_input_4_AL_l2...                0.695450
# 03_mouse_BL6_M_26month_SOX9_input_AL_l20200911_...                0.687088
#
#                                                     mappedFraction  \
# 00_mouse_BL6_M_3week_SOX9_input_AL_l20200911_TC...        0.978308
# 01_mouse_BL6_M_3month_SOX9_input_13_JOS_l202002...        0.961193
# 01_mouse_BL6_M_3month_SOX9_input_14_JOS_l202002...        0.956292
# 01_mouse_BL6_M_3month_SOX9_input_1_AL_20200205_...        0.000000
# 01_mouse_BL6_M_3month_SOX9_input_2012_JOS_l2020...        0.953886
# 01_mouse_BL6_M_3month_SOX9_input_2_AL_20200205_...        0.961193
# 01_mouse_BL6_M_3month_SOX9_input_BL6_1_input_AL...        0.950475
# 02_mouse_MPSIIIAhet_M_4month_SOX9_input_4_AL_l2...        0.950795
# 03_mouse_BL6_M_26month_SOX9_input_AL_l20200911_...        0.946743
#
#                                                     frac_unmappedReads_mismatch  \
# 00_mouse_BL6_M_3week_SOX9_input_AL_l20200911_TC...                          NaN
# 01_mouse_BL6_M_3month_SOX9_input_13_JOS_l202002...                          NaN
# 01_mouse_BL6_M_3month_SOX9_input_14_JOS_l202002...                          NaN
# 01_mouse_BL6_M_3month_SOX9_input_1_AL_20200205_...                          0.0
# 01_mouse_BL6_M_3month_SOX9_input_2012_JOS_l2020...                          NaN
# 01_mouse_BL6_M_3month_SOX9_input_2_AL_20200205_...                          NaN
# 01_mouse_BL6_M_3month_SOX9_input_BL6_1_input_AL...                          NaN
# 02_mouse_MPSIIIAhet_M_4month_SOX9_input_4_AL_l2...                          NaN
# 03_mouse_BL6_M_26month_SOX9_input_AL_l20200911_...                          NaN
#
#                                                     frac_unmappedReads_short  \
# 00_mouse_BL6_M_3week_SOX9_input_AL_l20200911_TC...                       NaN
# 01_mouse_BL6_M_3month_SOX9_input_13_JOS_l202002...                       NaN
# 01_mouse_BL6_M_3month_SOX9_input_14_JOS_l202002...                       NaN
# 01_mouse_BL6_M_3month_SOX9_input_1_AL_20200205_...                       0.0
# 01_mouse_BL6_M_3month_SOX9_input_2012_JOS_l2020...                       NaN
# 01_mouse_BL6_M_3month_SOX9_input_2_AL_20200205_...                       NaN
# 01_mouse_BL6_M_3month_SOX9_input_BL6_1_input_AL...                       NaN
# 02_mouse_MPSIIIAhet_M_4month_SOX9_input_4_AL_l2...                       NaN
# 03_mouse_BL6_M_26month_SOX9_input_AL_l20200911_...                       NaN
#
#                                                     frac_unmappedReads_other
# 00_mouse_BL6_M_3week_SOX9_input_AL_l20200911_TC...                       NaN
# 01_mouse_BL6_M_3month_SOX9_input_13_JOS_l202002...                       NaN
# 01_mouse_BL6_M_3month_SOX9_input_14_JOS_l202002...                       NaN
# 01_mouse_BL6_M_3month_SOX9_input_1_AL_20200205_...                       0.0
# 01_mouse_BL6_M_3month_SOX9_input_2012_JOS_l2020...                       NaN
# 01_mouse_BL6_M_3month_SOX9_input_2_AL_20200205_...                       NaN
# 01_mouse_BL6_M_3month_SOX9_input_BL6_1_input_AL...                       NaN
# 02_mouse_MPSIIIAhet_M_4month_SOX9_input_4_AL_l2...                       NaN
# 03_mouse_BL6_M_26month_SOX9_input_AL_l20200911_...                       NaN

# %% [markdown]
# ### Plot tag count distribution

# %%
# tds = glob.glob(dataDirectory+'/*')
# tds = np.sort(tds)

# fig, axs = plt.subplots(2,3, figsize=(15, 10), sharex=True, sharey=True)

# for ax, td in zip(axs.flatten(), tds):
#     df = pd.read_csv(td+'/tagCountDistribution.txt', sep='\t', index_col=0)
#     df.loc[1:10, :].plot.bar(ax=ax, legend=False)
#     ax.set_xlabel('Tags per position')
#     ax.set_ylabel('Fraction of Positions')
#     ax.set_title(td.split('/')[-1].split('_AL')[0], fontsize=8)

# %% [markdown]
# # make browser hub
#
# Browser hub naming strategy (CapitalizeFirstLetters):
# hrb_project_qc/viz_celltype_ChIPTarget/input
#
# Browser color strategy:
# * QC:
#     * Sox9: 99,99,99
#     * Olig2: 49,163,84
#     * NeuN: 222,45,38
#     * PU1: 49,130,189
# * Visualize: TBD

# %%
np.sort(os.listdir(dataDirectory))
# Out:
# array(['00_mouse_BL6_M_3week_SOX9_input_AL_l20200911_TCGATATC_ACACGAGT',
#        '01_mouse_BL6_M_3month_SOX9_input_13_JOS_l20200205_ATGTCA',
#        '01_mouse_BL6_M_3month_SOX9_input_14_JOS_l20200205_ATGTCA',
#        '01_mouse_BL6_M_3month_SOX9_input_1_AL_20200205_ATGTCA',
#        '01_mouse_BL6_M_3month_SOX9_input_2012_JOS_l20200205_ATGTCA',
#        '01_mouse_BL6_M_3month_SOX9_input_2_AL_20200205_GTGAAA',
#        '01_mouse_BL6_M_3month_SOX9_input_BL6_1_input_AL_l20200205_ATGTCA',
#        '02_mouse_MPSIIIAhet_M_4month_SOX9_input_4_AL_l20200925_TCGATATC_ACACGAGT',
#        '03_mouse_BL6_M_26month_SOX9_input_AL_l20200911_CTGCTTCC_GATAGATC'],
#       dtype='<U72')

# %%
makeMultiWigHub.pl hrb_BrainAging_QC_Sox9_Input mm10 \
-gradient 99,99,99 99,99,99 \
-force -d /data/mm10/Brain_MPSIIIA/ChIP/input/SOX9/*
# Out:
#   File "<ipython-input-8-4be1916e1147>", line 1
#     makeMultiWigHub.pl hrb_BrainAging_QC_Sox9_Input mm10 \
#                                                   ^
# SyntaxError: invalid syntax
