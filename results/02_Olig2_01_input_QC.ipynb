# %%
### header ###
__author__ = "Hunter Bennett"
__license__ = "BSD"
__email__ = "hunter.r.bennett@gmail.com"
# %load_ext autoreload
# %autoreload 2
### imports ###
import sys
# %matplotlib inline
import os
import re
import glob
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 200
sns.set(font_scale=1)
sns.set_context('talk')
sns.set_style('white')

# import custom functions
import sys
sys.path.insert(0, '/home/h1bennet/code/')
from hbUtils import ngs_qc, quantile_normalize_df

# %% [markdown]
# Set working directory

# %%
dataDirectory = '/data/mm10/Brain_MPSIIIA/ChIP/input/Olig2/WT//'
workingDirectory = '/home/h1bennet/mpsiiia/results/02_Olig2_H3K27Ac_QC/'
if not os.path.isdir(workingDirectory):
    os.mkdir(workingDirectory)
os.chdir(workingDirectory)

# %% [markdown]
# # Quality control

# %%
qc = ngs_qc(dataDirectory, 'atac')
# Out:
# /data/mm10/Brain_MPSIIIA/ChIP/input/Olig2/WT///
# ./WT_qc/

# %%
qc
# Out:
#                                                     uniquePositions  \
# 00_mouse_BL6_Olig2_ChIP_input_10_day_AL_l202009...        9211378.0
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAP21O...        5381824.0
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAWTP2...       11628775.0
# 01_mouse_MPSIIIAhet_M_P21_Olig2_input_1_AL_2019...       11628775.0
# 02_mouse_BL6_M_8week_Olig2_ChIP_input_1C_JOS_20...        1791360.0
# 02_mouse_BL6_M_8week_Olig2_input_1A_JOS_2019080...        1791360.0
# 02_mouse_BL6_M_8week_Olig2_input_1B_JOS_2019080...        1791360.0
# 02_mouse_BL6_M_Olig2_ChIP_input_BL68week1input_...        9284249.0
# 03_mouse_MPSIIIAhet_Olig2_ChIP_input_4_month_AL...       10588424.0
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAP24...        7471143.0
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAWTP...       12951576.0
# 04_mouse_MPSIIIAhet_M_P240_Olig2_input_2_AL_201...       12951576.0
#
#                                                     fragmentLengthEstimate  \
# 00_mouse_BL6_Olig2_ChIP_input_10_day_AL_l202009...                   226.0
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAP21O...                   226.0
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAWTP2...                   180.0
# 01_mouse_MPSIIIAhet_M_P21_Olig2_input_1_AL_2019...                   180.0
# 02_mouse_BL6_M_8week_Olig2_ChIP_input_1C_JOS_20...                   227.0
# 02_mouse_BL6_M_8week_Olig2_input_1A_JOS_2019080...                   227.0
# 02_mouse_BL6_M_8week_Olig2_input_1B_JOS_2019080...                   227.0
# 02_mouse_BL6_M_Olig2_ChIP_input_BL68week1input_...                    80.0
# 03_mouse_MPSIIIAhet_Olig2_ChIP_input_4_month_AL...                   185.0
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAP24...                    80.0
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAWTP...                   161.0
# 04_mouse_MPSIIIAhet_M_P240_Olig2_input_2_AL_201...                   161.0
#
#                                                     tagsPerBP  clonality  \
# 00_mouse_BL6_Olig2_ChIP_input_10_day_AL_l202009...   0.004243      1.256
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAP21O...   0.002127      1.077
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAWTP2...   0.004420      1.036
# 01_mouse_MPSIIIAhet_M_P21_Olig2_input_1_AL_2019...   0.004420      1.036
# 02_mouse_BL6_M_8week_Olig2_ChIP_input_1C_JOS_20...   0.000691      1.052
# 02_mouse_BL6_M_8week_Olig2_input_1A_JOS_2019080...   0.000691      1.052
# 02_mouse_BL6_M_8week_Olig2_input_1B_JOS_2019080...   0.000691      1.052
# 02_mouse_BL6_M_Olig2_ChIP_input_BL68week1input_...   0.003558      1.045
# 03_mouse_MPSIIIAhet_Olig2_ChIP_input_4_month_AL...   0.004089      1.053
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAP24...   0.002882      1.052
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAWTP...   0.004993      1.051
# 04_mouse_MPSIIIAhet_M_P240_Olig2_input_2_AL_201...   0.004993      1.051
#
#                                                     GC_Content  totalReads  \
# 00_mouse_BL6_Olig2_ChIP_input_10_day_AL_l202009...       0.406  13238986.0
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAP21O...       0.411   9659342.0
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAWTP2...       0.419  16659690.0
# 01_mouse_MPSIIIAhet_M_P21_Olig2_input_1_AL_2019...       0.419  16659690.0
# 02_mouse_BL6_M_8week_Olig2_ChIP_input_1C_JOS_20...       0.409   2877394.0
# 02_mouse_BL6_M_8week_Olig2_input_1A_JOS_2019080...       0.409   2877394.0
# 02_mouse_BL6_M_8week_Olig2_input_1B_JOS_2019080...       0.409   2877394.0
# 02_mouse_BL6_M_Olig2_ChIP_input_BL68week1input_...       0.407  13321041.0
# 03_mouse_MPSIIIAhet_Olig2_ChIP_input_4_month_AL...       0.422  14798710.0
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAP24...       0.401  10119468.0
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAWTP...       0.416  19651017.0
# 04_mouse_MPSIIIAhet_M_P240_Olig2_input_2_AL_201...       0.416  19651017.0
#
#                                                     uniquelyMappedReads  \
# 00_mouse_BL6_Olig2_ChIP_input_10_day_AL_l202009...           10268231.0
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAP21O...            5765097.0
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAWTP2...           11607710.0
# 01_mouse_MPSIIIAhet_M_P21_Olig2_input_1_AL_2019...           11607710.0
# 02_mouse_BL6_M_8week_Olig2_ChIP_input_1C_JOS_20...            1839588.0
# 02_mouse_BL6_M_8week_Olig2_input_1A_JOS_2019080...            1839588.0
# 02_mouse_BL6_M_8week_Olig2_input_1B_JOS_2019080...            1839588.0
# 02_mouse_BL6_M_Olig2_ChIP_input_BL68week1input_...            9238020.0
# 03_mouse_MPSIIIAhet_Olig2_ChIP_input_4_month_AL...           10169270.0
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAP24...            7283787.0
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAWTP...           13245678.0
# 04_mouse_MPSIIIAhet_M_P240_Olig2_input_2_AL_201...           13245678.0
#
#                                                     multiMappedReads  \
# 00_mouse_BL6_Olig2_ChIP_input_10_day_AL_l202009...         2781932.0
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAP21O...         1855773.0
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAWTP2...         3390239.0
# 01_mouse_MPSIIIAhet_M_P21_Olig2_input_1_AL_2019...         3390239.0
# 02_mouse_BL6_M_8week_Olig2_ChIP_input_1C_JOS_20...          613176.0
# 02_mouse_BL6_M_8week_Olig2_input_1A_JOS_2019080...          613176.0
# 02_mouse_BL6_M_8week_Olig2_input_1B_JOS_2019080...          613176.0
# 02_mouse_BL6_M_Olig2_ChIP_input_BL68week1input_...         2845187.0
# 03_mouse_MPSIIIAhet_Olig2_ChIP_input_4_month_AL...         3765078.0
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAP24...         2177518.0
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAWTP...         3718981.0
# 04_mouse_MPSIIIAhet_M_P240_Olig2_input_2_AL_201...         3718981.0
#
#                                                     unmappedReads  \
# 00_mouse_BL6_Olig2_ChIP_input_10_day_AL_l202009...       188823.0
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAP21O...      2038472.0
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAWTP2...      1661741.0
# 01_mouse_MPSIIIAhet_M_P21_Olig2_input_1_AL_2019...      1661741.0
# 02_mouse_BL6_M_8week_Olig2_ChIP_input_1C_JOS_20...       424630.0
# 02_mouse_BL6_M_8week_Olig2_input_1A_JOS_2019080...       424630.0
# 02_mouse_BL6_M_8week_Olig2_input_1B_JOS_2019080...       424630.0
# 02_mouse_BL6_M_Olig2_ChIP_input_BL68week1input_...      1237834.0
# 03_mouse_MPSIIIAhet_Olig2_ChIP_input_4_month_AL...       864362.0
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAP24...       658163.0
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAWTP...      2686358.0
# 04_mouse_MPSIIIAhet_M_P240_Olig2_input_2_AL_201...      2686358.0
#
#                                                     uniquelyMappedFraction  \
# 00_mouse_BL6_Olig2_ChIP_input_10_day_AL_l202009...                0.775606
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAP21O...                0.596842
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAWTP2...                0.696754
# 01_mouse_MPSIIIAhet_M_P21_Olig2_input_1_AL_2019...                0.696754
# 02_mouse_BL6_M_8week_Olig2_ChIP_input_1C_JOS_20...                0.639324
# 02_mouse_BL6_M_8week_Olig2_input_1A_JOS_2019080...                0.639324
# 02_mouse_BL6_M_8week_Olig2_input_1B_JOS_2019080...                0.639324
# 02_mouse_BL6_M_Olig2_ChIP_input_BL68week1input_...                0.693491
# 03_mouse_MPSIIIAhet_Olig2_ChIP_input_4_month_AL...                0.687173
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAP24...                0.719780
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAWTP...                0.674045
# 04_mouse_MPSIIIAhet_M_P240_Olig2_input_2_AL_201...                0.674045
#
#                                                     mappedFraction
# 00_mouse_BL6_Olig2_ChIP_input_10_day_AL_l202009...        0.985737
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAP21O...        0.788964
# 01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAWTP2...        0.900254
# 01_mouse_MPSIIIAhet_M_P21_Olig2_input_1_AL_2019...        0.900254
# 02_mouse_BL6_M_8week_Olig2_ChIP_input_1C_JOS_20...        0.852425
# 02_mouse_BL6_M_8week_Olig2_input_1A_JOS_2019080...        0.852425
# 02_mouse_BL6_M_8week_Olig2_input_1B_JOS_2019080...        0.852425
# 02_mouse_BL6_M_Olig2_ChIP_input_BL68week1input_...        0.907077
# 03_mouse_MPSIIIAhet_Olig2_ChIP_input_4_month_AL...        0.941592
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAP24...        0.934961
# 04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAWTP...        0.863297
# 04_mouse_MPSIIIAhet_M_P240_Olig2_input_2_AL_201...        0.863297

# %% [markdown]
# ### Plot tag count distribution

# %%
# tds = glob.glob(dataDirectory+'/*')
# tds = np.sort(tds)

# fig, axs = plt.subplots(2,3, figsize=(15, 10), sharex=True, sharey=True)

# for ax, td in zip(axs.flatten(), tds):
#     df = pd.read_csv(td+'/tagCountDistribution.txt', sep='\t', index_col=0)
#     df.loc[1:10, :].plot.bar(ax=ax, legend=False)
#     ax.set_xlabel('Tags per position')
#     ax.set_ylabel('Fraction of Positions')
#     ax.set_title(td.split('/')[-1].split('_AL')[0], fontsize=8)

# %% [markdown]
# # make browser hub
#
# Browser hub naming strategy (CapitalizeFirstLetters):
# hrb_project_qc/viz_celltype_ChIPTarget/input
#
# Browser color strategy:
# * QC:
#     * Sox9: 99,99,99
#     * Olig2: 49,163,84
#     * NeuN: 222,45,38
#     * PU1: 49,130,189
# * Visualize: TBD

# %%
np.sort(os.listdir(dataDirectory))
# Out:
# array(['00_mouse_BL6_Olig2_ChIP_input_10_day_AL_l20200911_AACTGTAG_ACGCCGCA',
#        '01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAP21Olig2_416_AL_l20191206_TCCCGA',
#        '01_mouse_C57_M_P21_Olig2_ChIP_input_MPSIIIAWTP21Olig2_410_AL_l20191122_CTCAGA',
#        '01_mouse_MPSIIIAhet_M_P21_Olig2_input_1_AL_20191122_CTCAGA',
#        '02_mouse_BL6_M_8week_Olig2_ChIP_input_1C_JOS_20190801_CCAACA',
#        '02_mouse_BL6_M_8week_Olig2_input_1A_JOS_20190801_CCAACA',
#        '02_mouse_BL6_M_8week_Olig2_input_1B_JOS_20190801_CCAACA',
#        '02_mouse_BL6_M_Olig2_ChIP_input_BL68week1input_465_AL_l20191226_CAGGCG',
#        '03_mouse_MPSIIIAhet_Olig2_ChIP_input_4_month_AL_l20200925_AAGTCCAA_TATGAGTA',
#        '04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAP240Olig2_433_AL_l20191206_TGACCA',
#        '04_mouse_C57_M_P240_Olig2_ChIP_input_MPSIIIAWTP240Olig2_407_AL_l20191122_CGGAAT',
#        '04_mouse_MPSIIIAhet_M_P240_Olig2_input_2_AL_20191122_CGGAAT'],
#       dtype='<U79')

# %%
makeMultiWigHub.pl hrb_BrainAging_QC_Olig2_Input mm10 \
-gradient 49,163,84 49,163,84 \
-force -d /data/mm10/Brain_MPSIIIA/ChIP/input/Olig2/WT/*
# Out:
#   File "<ipython-input-8-4be1916e1147>", line 1
#     makeMultiWigHub.pl hrb_BrainAging_QC_Sox9_Input mm10 \
#                                                   ^
# SyntaxError: invalid syntax
